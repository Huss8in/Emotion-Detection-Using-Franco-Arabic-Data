# %%
import pandas as pd

df =  pd.read_csv('datasets/500_afterEmbedding.csv')
df
# Out:
#                                          text    emotion  \
# 0                       kefaya awe mara wa7da    neutral
# 1     ana enbhart w etfg2t awii b7aga zay kda   surprise
# 2      el 7war da kol mftkro o3od ad7ak awiii  happiness
# 3                            mt3sbnesh mashy!      angry
# 4    gatko nela shba kan kwayez b2a w7sh awii      angry
# ..                                        ...        ...
# 495                  eh el araf da ana mt3sab      angry
# 496                   tab law omt w gbthalk..    neutral
# 497                 ana msh msda2 ana masdoom   surprise
# 498                eh el mofg2at el 8areba de   surprise
# 499                                 mashy :')    neutral
#
#                                    clean_text  \
# 0                       kefaya awe mara wa7da
# 1     ana enbhart w etfg2t awii b7aga zay kda
# 2      el 7war da kol mftkro o3od ad7ak awiii
# 3                             mt3sbnesh mashy
# ...

# %%
# Separate features and labels
X = df['text']
y = df['emotion']

# Convert labels to numerical values
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Apply SMOTE to the training data only
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

# Convert back to DataFrame if needed
X_train_balanced_df = pd.DataFrame(X_train_balanced, columns=['text'])
y_train_balanced_df = pd.DataFrame(y_train_balanced, columns=['emotion'])

# Concatenate the balanced data
df_balanced = pd.concat([X_train_balanced_df, y_train_balanced_df], axis=1)

# Check the class distribution after balancing
print(df_balanced['emotion'].value_counts())

# Now, you can use df_balanced for training your NLP model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\husse\Desktop\Emotional_Detection_3_Dec\test.ipynb Cell 2 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/husse/Desktop/Emotional_Detection_3_Dec/test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> y = df['emotion']
#       <a href='vscode-notebook-cell:/c%3A/Users/husse/Desktop/Emotional_Detection_3_Dec/test.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> # Convert labels to numerical values
# ----> <a href='vscode-notebook-cell:/c%3A/Users/husse/Desktop/Emotional_Detection_3_Dec/test.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> le = LabelEncoder()
#       <a href='vscode-notebook-cell:/c%3A/Users/husse/Desktop/Emotional_Detection_3_Dec/test.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> y_encoded = le.fit_transform(y)
# ...

# %%
# import openai

# openai_api_key = "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"

# def augment_text_with_emotion(text, emotion):
#     openai.api_key = openai_api_key
#     prompt = f"Translate the following Arabic text with emotion '{text}' into English: '{emotion}'"
#     response = openai.Completion.create(
#         engine="text-davinci-003",
#         prompt=prompt,
#         temperature=0.7,
#         max_tokens=150,
#         n=1,
#         stop=None,
#     )
#     augmented_text = response.choices[0].text.strip()
#     return augmented_text

# # Apply the augmented function to your DataFrame
# df['augmented_text'] = df.apply(lambda row: augment_text_with_emotion(row['arabic_text'], row['emotion']), axis=1)
